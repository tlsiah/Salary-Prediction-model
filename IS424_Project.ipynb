# %% [markdown]
# # Import the necessary packages

# %%
import numpy as np
import pandas as pd 

# packages for categorical encoding 

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# # Import the dataset

# %%
df = pd.read_csv('data_cleaned_2021.csv')
df.sample(5)
# Out:
#      index                                          Job Title  \
# 173    205                                Senior Data Analyst
# 27      28                             Associate Data Analyst
# 738    951                               Senior Data Engineer
# 352    449                              Senior Data Scientist
# 633    809  Research Scientist or Senior Research Scientis...
#
#                   Salary Estimate  \
# 173   $55K-$100K (Glassdoor est.)
# 27     $34K-$61K (Glassdoor est.)
# 738   $72K-$133K (Glassdoor est.)
# 352  $108K-$171K (Glassdoor est.)
# 633   $81K-$161K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 173  As a precaution and in compliance with applica...     2.8
# 27   Friday, January 17, 2020\n\nOur Enterprise Dat...     3.7
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 352  The Infrastructure, Architecture, and Tools te...     4.4
# ...

# %%
# number of rows and columns 
df.shape
# Out:
# (742, 42)

# %%
# data types of the individual columns 
df.dtypes
# Out:
# index                   int64
# Job Title              object
# Salary Estimate        object
# Job Description        object
# Rating                float64
# Company Name           object
# Location               object
# Headquarters           object
# Size                   object
# Founded                 int64
# Type of ownership      object
# Industry               object
# Sector                 object
# Revenue                object
# Competitors            object
# Hourly                  int64
# Employer provided       int64
# Lower Salary            int64
# Upper Salary            int64
# Avg Salary(K)         float64
# company_txt            object
# Job Location           object
# Age                     int64
# Python                  int64
# spark                   int64
# aws                     int64
# excel                   int64
# sql                     int64
# sas                     int64
# keras                   int64
# pytorch                 int64
# ...

# %%
df.nunique()
# Out:
# index                      742
# Job Title                  264
# Salary Estimate            416
# Job Description            463
# Rating                      31
# Company Name               343
# Location                   200
# Headquarters               198
# Size                         8
# Founded                    102
# Type of ownership            9
# Industry                    60
# Sector                      25
# Revenue                     13
# Competitors                128
# Hourly                       2
# Employer provided            2
# Lower Salary               113
# Upper Salary               162
# Avg Salary(K)              219
# company_txt                343
# Job Location                37
# Age                        102
# Python                       2
# spark                        2
# aws                          2
# excel                        2
# sql                          2
# sas                          2
# keras                        2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    742 non-null    int64
#  1   Job Title                742 non-null    object
#  2   Salary Estimate          742 non-null    object
#  3   Job Description          742 non-null    object
#  4   Rating                   742 non-null    float64
#  5   Company Name             742 non-null    object
#  6   Location                 742 non-null    object
#  7   Headquarters             742 non-null    object
#  8   Size                     742 non-null    object
#  9   Founded                  742 non-null    int64
#  10  Type of ownership        742 non-null    object
#  11  Industry                 742 non-null    object
#  12  Sector                   742 non-null    object
#  13  Revenue                  742 non-null    object
# ...

# %% [markdown]
# <b> Statistical Summary of Data <b>

# %%
print(df.describe())
# Out:
#             index      Rating      Founded      Hourly  Employer provided  \
# count  742.000000  742.000000   742.000000  742.000000         742.000000
# mean   469.129380    3.618868  1837.154987    0.032345           0.022911
# std    279.793117    0.801210   497.183763    0.177034           0.149721
# min      0.000000   -1.000000    -1.000000    0.000000           0.000000
# 25%    221.500000    3.300000  1939.000000    0.000000           0.000000
# 50%    472.500000    3.700000  1988.000000    0.000000           0.000000
# 75%    707.750000    4.000000  2007.000000    0.000000           0.000000
# max    955.000000    5.000000  2019.000000    1.000000           1.000000
#
#        Lower Salary  Upper Salary  Avg Salary(K)         Age      Python  ...  \
# count    742.000000    742.000000     742.000000  742.000000  742.000000  ...
# mean      74.754717    128.214286     101.484501   47.524259    0.528302  ...
# ...

# %% [markdown]
# # Data Preprocessing
# Dealing with outliers and encode categorical variables

# %% [markdown]
# <b> Label Encoding <b>

# %%
labelencoder = LabelEncoder()
# Target column:
df['salary_estimate_encoded'] = labelencoder.fit_transform(df['Salary Estimate'])
df.sample(5)
# Out:
#      index                                          Job Title  \
# 345    437                      Clinical Laboratory Scientist
# 648    826  Assistant Director/Director, Office of Data Sc...
# 693    893                              Senior Data Scientist
# 683    877  Data Analyst 1, full-time contract worker for ...
# 469    601                   Software Data Engineer - College
#
#                           Salary Estimate  \
# 345      $24-$39 Per Hour(Glassdoor est.)
# 648            $39K-$67K (Glassdoor est.)
# 693  Employer Provided Salary:$120K-$140K
# 683            $35K-$65K (Glassdoor est.)
# 469            $49K-$97K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 345  POSITION PURPOSE:\nPerforms CLIA moderate and ...     3.7
# 648  Advance your career at Liberty Mutual - A Fort...     3.3
# 693  SkySync is a dynamic, fast-paced, venture-back...     5.0
# 683  Purposes\n\nIn addition to your application, p...     4.2
# ...

# %% [markdown]
# <b> One-Hot Encoding <b>

# %%
labelbinarizer = LabelBinarizer()
x = labelbinarizer.fit_transform(df["Salary Estimate"])
encoded_df = pd.DataFrame(x, columns=labelbinarizer.classes_)
df = pd.concat([df, encoded_df], axis=1)
df.sample(10)
# Out:
#      index                                          Job Title  \
# 102    116                    Data Scientist, Rice University
# 617    786                        Medical Lab Scientist - MLT
# 426    544               Computational Chemist/Data Scientist
# 101    113                                     Data Scientist
# 532    681     Staff Scientist-Downstream Process Development
# 709    914                          Machine Learning Engineer
# 252    313                  Scientist, Analytical Development
# 188    225  Principal Data Scientist (Computational Chemis...
# 546    698                          Revenue Analytics Manager
# 2        2                                     Data Scientist
#
#                       Salary Estimate  \
# 102       $65K-$110K (Glassdoor est.)
# 617  $21-$29 Per Hour(Glassdoor est.)
# 426        $56K-$97K (Glassdoor est.)
# 101       $61K-$110K (Glassdoor est.)
# 532       $49K-$113K (Glassdoor est.)
# 709       $91K-$159K (Glassdoor est.)
# ...
